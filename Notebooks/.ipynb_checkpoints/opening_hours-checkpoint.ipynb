# %%
def get_opening_hours_from_osm_data(path_to_osm_geojson):
    """
        path_to_osm_geojson (geojson): path to the geojson file. We get data from https://download.bbbike.org/osm/bbbike/ 
    """

    f = open(path_to_osm_geojson, "r")
    all_lines = f.readlines()
    print("Number of lines in file:", len(all_lines))

    line_index = 0
    opening_hours_indexes = []
    
    f = open(path_to_osm_geojson, "r")
    for x in f:
        if 'opening_hours' in x:
            opening_hours_indexes.append(line_index)
        line_index += 1
    print("Number of opening_hours entries:", len(opening_hours_indexes))
    return all_lines, opening_hours_indexes


def write_opening_hours_to_geojson(path_to_output_geojson, all_lines, opening_hours_indexes):
    """
        all_lines (list): all lines in the overall file
        
    """
    with open(path_to_output_geojson, "w+") as my_file:
        my_file.write(all_lines[0])
        for line in opening_hours_indexes[:-1]:
            my_file.write(all_lines[line])
        # remove comma from final line
        final_line = all_lines[opening_hours_indexes[-1]].replace(",\n","\n")
        my_file.write(final_line)
        my_file.write(all_lines[-1])
        my_file.close()

# %%
all_lines, opening_hours_indexes = get_opening_hours_from_osm_data(path_to_osm_geojson="../Data/shapes/Montreal.osm.geojson")
# Out:
# Number of lines in file: 973099
# Number of opening_hours entries: 2049

# %%
write_opening_hours_to_geojson(all_lines=all_lines, opening_hours_indexes=opening_hours_indexes, path_to_output_geojson="../Data/model_inputs/mtl_opening_hours.geojson")

# %%
import geopandas as gpd

# %%
all_opening_hours = gpd.read_file("../Data/model_inputs/mtl_opening_hours.geojson")

# %%
all_opening_hours['opening_hours']
# Out:
# 0                               We-Su 10:00-17:00; Mo off
# 1                                       Mo-Su 11:00-23:00
# 2                                              6:00-22:00
# 3                                       Mo-Su 08:00-22:00
# 4                       Mo-Sa 06:00-15:00, Su 07:00-15:00
#                               ...
# 2044                 Mo-Fr 09:00-18:00; Sa-Su 09:00-17:00
# 2045                    Mo-Fr 08:30-18:00; Sa 08:00-13:00
# 2046    Apr-Nov: Th-Tu 08:00-17:00;Nov-Apr: Su 08:00-1...
# 2047                                           6:00-22:00
# 2048                                           6:00-22:00
# Name: opening_hours, Length: 2049, dtype: object

# %%
all_opening_hours['shop'].value_counts()
# Out:
# supermarket     98
# convenience     72
# clothes         65
# hairdresser     46
# bakery          39
#                 ..
# carpet           1
# anime            1
# food             1
# estate_agent     1
# beverages        1
# Name: shop, Length: 107, dtype: int64

# %%
all_opening_hours['tourism'].value_counts()
# Out:
# museum         14
# gallery         5
# attraction      3
# guest_house     2
# apartment       2
# yes             2
# hotel           2
# Name: tourism, dtype: int64

# %%
all_opening_hours['amenity'].value_counts() # pharamacy, school
# Out:
# restaurant                357
# cafe                      135
# fast_food                  97
# pharmacy                   59
# bank                       55
# bar                        41
# library                    31
# fuel                       28
# pub                        18
# bicycle_repair_station     16
# clinic                     13
# atm                        12
# veterinary                 12
# post_office                12
# dentist                    11
# ice_cream                  10
# car_rental                 10
# social_facility             8
# parking                     7
# community_centre            6
# charging_station            6
# bureau_de_change            6
# marketplace                 4
# toilets                     3
# recycling                   3
# shop|clothes                3
# childcare                   3
# nightclub                   3
# driving_school              3
# food_court                  2
# car_wash                    2
# dojo                        2
# theatre                     2
# embassy                     2
# school                      2
# arts_centre                 2
# car_sharing                 2
# water_point                 1
# audiologist                 1
# hospital                    1
# bicycle_parking             1
# doctors                     1
# sanitary_dump_station       1
# cinema                      1
# social_centre               1
# bicycle_rental              1
# coworking_space             1
# animal_boarding             1
# language_school             1
# animal_shelter              1
# vehicle_inspection          1
# police                      1
# internet_cafe               1
# ferry_terminal              1
# Name: amenity, dtype: int64

# %%
all_opening_hours['healthcare'].value_counts()
# Out:
# pharmacy           42
# dentist             4
# clinic              4
# alternative         2
# physiotherapist     2
# centre              2
# hospital            1
# Name: healthcare, dtype: int64

# %%
all_opening_hours['leisure'].value_counts()
# Out:
# park              34
# fitness_centre    11
# sports_centre      9
# ice_rink           4
# garden             2
# picnic_table       2
# tanning_salon      2
# hackerspace        2
# playground         2
# dog_park           2
# bowling_alley      2
# sauna              1
# dance              1
# horse_riding       1
# Name: leisure, dtype: int64

# %%
all_opening_hours['sport'].value_counts()
# Out:
# climbing                                          3
# skating;hockey                                    2
# billiards                                         2
# 10pin                                             2
# yoga;pilates;essentrics                           2
# Skating, Hockey, Basketball                       2
# All                                               1
# karate;boxing;kickboxing;exercise;martial_arts    1
# Kenjutsu                                          1
# kendo                                             1
# Name: sport, dtype: int64

# %%
all_opening_hours['building'].value_counts()
# Out:
# yes                212
# retail              40
# roof                10
# commercial           8
# civic                6
# public               6
# public_building      2
# farm_auxiliary       2
# library              2
# garage               2
# university           2
# residential          2
# hotel                2
# office               1
# warehouse            1
# Name: building, dtype: int64

# %%
all_opening_hours['craft'].value_counts()
# Out:
# tailor                4
# shoemaker             4
# electronics_repair    3
# brewery               2
# electrician           1
# construction          1
# sign_maker            1
# gardener              1
# optician              1
# mason                 1
# floorer               1
# locksmith             1
# caterer               1
# handicraft            1
# Name: craft, dtype: int64

# %%
for col in all_opening_hours.columns[1:]:
    print(col)
    print(all_opening_hours[col].value_counts())
# Out:
# name
# McDonald's        25
# Pharmaprix        23
# Tim Hortons       21
# Service Canada    16
# A&W               10
#                   ..
# Le Blueboy         1
# Aqu@net            1
# FOFA Gallery       1
# Globex 2000        1
# Touchattou         1
# Name: name, Length: 1554, dtype: int64
# phone
# +1 514 937 7620    3
# +1 514 485 3543    2
# +1-450-736-1323    2
# +1-514-271-9622    2
# +1-800-363-9028    2
#                   ..
# +1-514-419-7997    1
# +1-514-483-7777    1
# +1-514-625-3061    1
# +1-514-663-8042    1
# +1 514 274 0919    1
# Name: phone, Length: 839, dtype: int64
# name:en
# National Bank                                           3
# Heinz Garage                                            2
# Hymus Auto Parts                                        2
# Costco Gas                                              2
# Shoppers Drug Mart                                      2
#                                                        ..
# Olive + gourmando                                       1
# LOV                                                     1
# Austrian Ski Shop                                       1
# Canada Post                                             1
# Consulate General of the Federal Republic of Germany    1
# Name: name:en, Length: 74, dtype: int64
# tourism
# museum         14
# gallery         5
# attraction      3
# guest_house     2
# apartment       2
# yes             2
# hotel           2
# Name: tourism, dtype: int64
# wikidata
# Q22476946    2
# Q1496027     2
# Q11845348    2
# Q22477136    2
# Q3390159     2
# Q168737      2
# Q16506938    2
# Q3114903     2
# Q1629577     2
# Q23824556    1
# Q2864894     1
# Q27097050    1
# Q8001601     1
# Q7775786     1
# Q5287679     1
# Q17623881    1
# Q3041361     1
# Q3237901     1
# Q3578612     1
# Q860812      1
# Q3475576     1
# Name: wikidata, dtype: int64
# wikipedia
# fr:Parc de Dieppe                             2
# fr:Château Ramezay                            2
# fr:Grande Bibliothèque                        2
# en:Jean-Talon Market                          2
# fr:Marché Bonsecours                          2
# fr:L'Insoumise (librairie)                    2
# en:Musée d'art contemporain de Montréal       2
# en:Pointe-à-Callière Museum                   2
# fr:Bibliothèque Langelier                     1
# fr:Artexte                                    1
# en:Montreal Museum of Fine Arts               1
# fr:Centre communautaire LGBTQ+ de Montréal    1
# Name: wikipedia, dtype: int64
# wheelchair
# yes        195
# no          86
# limited     35
# Name: wheelchair, dtype: int64
# alt_name:en
# Museum of Fine Arts    1
# Name: alt_name:en, dtype: int64
# alt_name:fr
# Musée des Beaux-Arts    1
# Name: alt_name:fr, dtype: int64
# opening_hours
# 24/7                                                     147
# Mo-Su 08:00-22:00                                         25
# Mo-Fr 08:30-16:00                                         18
# Mo-Su 08:00-21:00                                         14
# Mo-Su 06:00-24:00                                         14
#                                                         ...
# Mo-Su 08:00-18:00+                                         1
# Mo-We 09:00-20:00;Th-Fr 09:00-21:00;Sa-Su 09:00-18:00      1
# Mo-Fr 11:00-18:00                                          1
# Mo-Th 10:00-21:00, Fr-Su 10:00-17:00                       1
# Mo-Fr 09:00-18:00; Sa 09:00-17:00; Su 11:00-16:00          1
# Name: opening_hours, Length: 1428, dtype: int64
# amenity
# restaurant                357
# cafe                      135
# fast_food                  97
# pharmacy                   59
# bank                       55
# bar                        41
# library                    31
# fuel                       28
# pub                        18
# bicycle_repair_station     16
# clinic                     13
# atm                        12
# veterinary                 12
# post_office                12
# dentist                    11
# ice_cream                  10
# car_rental                 10
# social_facility             8
# parking                     7
# community_centre            6
# charging_station            6
# bureau_de_change            6
# marketplace                 4
# toilets                     3
# recycling                   3
# shop|clothes                3
# childcare                   3
# nightclub                   3
# driving_school              3
# food_court                  2
# car_wash                    2
# dojo                        2
# theatre                     2
# embassy                     2
# school                      2
# arts_centre                 2
# car_sharing                 2
# water_point                 1
# audiologist                 1
# hospital                    1
# bicycle_parking             1
# doctors                     1
# sanitary_dump_station       1
# cinema                      1
# social_centre               1
# bicycle_rental              1
# coworking_space             1
# animal_boarding             1
# language_school             1
# animal_shelter              1
# vehicle_inspection          1
# police                      1
# internet_cafe               1
# ferry_terminal              1
# Name: amenity, dtype: int64
# cuisine
# coffee_shop                         53
# burger                              42
# pizza                               23
# sushi                               17
# italian                             14
#                                     ..
# british                              1
# bagel;cake;coffee_shop;ice_cream     1
# hotdog;burger;breakfast              1
# tea_shop                             1
# pizza;regional;italian               1
# Name: cuisine, Length: 104, dtype: int64
# smoking
# no          72
# outside     14
# isolated     2
# Name: smoking, dtype: int64
# capacity
# 50     6
# 30     5
# 75     5
# 20     5
# 100    4
# 1      4
# 25     3
# 10     3
# 2      2
# 140    2
# 12     1
# 6      1
# 130    1
# 200    1
# 7      1
# Name: capacity, dtype: int64
# addr:city
# Montréal                      637
# Montreal                       41
# Laval                          35
# Brossard                       24
# Terrebonne                     11
# Sainte-Marthe-sur-le-Lac       10
# Saint-Laurent                  10
# Mercier                         8
# Lasalle                         7
# Pierrefonds                     7
# Verdun                          6
# Kirkland                        6
# Longueuil                       6
# Boucherville                    6
# Pointe-Claire                   5
# La Prairie                      4
# Outremont                       4
# Dollard-Des Ormeaux             4
# Sainte-Julie                    3
# Montréal-Ouest                  3
# Saint-Léonard                   2
# Saint-Hubert                    2
# Mirabel                         2
# Notre-Dame-de-l'Île-Perrot      2
# Westmount                       2
# Dollard-Des-Ormeaux             2
# Saint-Bruno                     1
# Sainte-Anne-de-Bellevue         1
# Pointe-aux-Trembles             1
# Vaudreuil-Dorion                1
# L'Île-Perrot                    1
# Anjou                           1
# Candiac                         1
# Repentigny                      1
# Sainte-Thérèse                  1
# Châteauguay                     1
# Montréa                         1
# Saint-Constant                  1
# Dorval                          1
# Mount Royal                     1
# Name: addr:city, dtype: int64
# addr:street
# Avenue du Mont-Royal Est    166
# Rue Ontario Est             128
# Rue Wellington               58
# Boulevard Saint-Laurent      56
# Rue Notre-Dame Ouest         44
#                            ...
# Jean-Talon Ouest              1
# Boulevard Bellerose Est       1
# Rue D'Iberville               1
# Avenue Léo-Lacombe            1
# Rue André-Laurendeau          1
# Name: addr:street, Length: 394, dtype: int64
# addr:postcode
# H2C 1T3    11
# H1W 1P9    11
# H1W 1R6    11
# J0N 1P0    10
# H1W 1S7     8
#            ..
# H2V 1S6     1
# H3X 1V1     1
# H2V 4G9     1
# H1Y 1H5     1
# H4P 1X4     1
# Name: addr:postcode, Length: 598, dtype: int64
# addr:province
# QC        376
# Québec    122
# Quebec     48
# Qc          6
# ON          1
# quebec      1
# qc          1
# Name: addr:province, dtype: int64
# addr:housenumber
# 1251    8
# 1000    7
# 350     6
# 280     6
# 100     6
#        ..
# 3330    1
# 2158    1
# 5220    1
# 4844    1
# 5185    1
# Name: addr:housenumber, Length: 1222, dtype: int64
# status
# closed    2
# Name: status, dtype: int64
# barrier
# gate    4
# Name: barrier, dtype: int64
# designation
# Brasseurs de quartier                     1
# Mode éthique, Designer Québécois          1
# crepe                                     1
# Clinique                                  1
# Café de quartier                          1
# St-Lambert Lock Cycle Link Gate (West)    1
# St-Lambert Lock Cycle Gate (East)         1
# Name: designation, dtype: int64
# shop
# supermarket     98
# convenience     72
# clothes         65
# hairdresser     46
# bakery          39
#                 ..
# carpet           1
# anime            1
# food             1
# estate_agent     1
# beverages        1
# Name: shop, Length: 107, dtype: int64
# website
# http://www.mcdonalds.ca/                                                 13
# https://www.maxi.ca/                                                      4
# https://www.artemano.ca/                                                  4
# https://www.saq.com/                                                      4
# https://www.renaissancequebec.ca                                          4
#                                                                          ..
# http://www.conceptplus.ca/                                                1
# https://www.rona.ca/fr/Centre-du-bricoleur-lachine-notre-dame-lachine     1
# https://www.insertech.ca/                                                 1
# https://espacelafontaine.com/                                             1
# https://daousteco.com                                                     1
# Name: website, Length: 680, dtype: int64
# atm
# yes    51
# Name: atm, dtype: int64
# ref
# 64           2
# 532          2
# CEB-10012    1
# 527          1
# CEB-10050    1
# CEB-10039    1
# 23100        1
# 4478         1
# CEB-10011    1
# Name: ref, dtype: int64
# brand
# McDonald's      25
# Tim Hortons     19
# Pharmaprix      16
# SAQ             11
# Jean Coutu      10
#                 ..
# CycloHalt        1
# Arc'teryx        1
# Thaï Express     1
# Sonic            1
# FTD flowers      1
# Name: brand, Length: 90, dtype: int64
# brand:wikidata
# Q38076       25
# Q175106      19
# Q1820137     16
# Q3488077     10
# Q3117457     10
#              ..
# Q11336224     1
# Q64924449     1
# Q277641       1
# Q509349       1
# Q5627799      1
# Name: brand:wikidata, Length: 79, dtype: int64
# brand:wikipedia
# en:McDonald's                            25
# en:Tim Hortons                           19
# en:Shoppers Drug Mart                    10
# en:Société des alcools du Québec         10
# en:Costco                                 9
#                                          ..
# en:Canadian Imperial Bank of Commerce     1
# en:Five Guys                              1
# en:Honda                                  1
# fr:La Belle Province (restaurant)         1
# en:Burger King                            1
# Name: brand:wikipedia, Length: 83, dtype: int64
# addr:suburb
# Le Plateau-Mont-Royal            23
# Rosemont-Petite-Patrie            7
# Côte-des-Neiges–NDG               4
# Mercier-Hochelaga-Maisonneuve     4
# Outremont                         2
# Ahuntsic-Cartierville             1
# Villeray-Saint-Michel-PE          1
# RDP-Pointe-Aux-Trembles           1
# Le Sud Ouest                      1
# Saint-Laurent                     1
# Saint-Leonard                     1
# Pointe-Claire                     1
# Verdun                            1
# Name: addr:suburb, dtype: int64
# internet_access
# wlan    144
# yes      19
# no        5
# wifi      2
# Name: internet_access, dtype: int64
# internet_access:fee
# no           55
# yes           5
# customers     1
# Name: internet_access:fee, dtype: int64
# operator
# Ville De Laval                              6
# Costco                                      5
# Metro                                       5
# Canada Post                                 4
# Loblaw Companies Limited                    4
#                                            ..
# Claude Heon                                 1
# Banque de Montréal                          1
# BMO Banque de Montréal                      1
# Arrondissement du Plateau-Mont-Royal        1
# Commission scolaire Marguerite-Bourgeoys    1
# Name: operator, Length: 108, dtype: int64
# dispensing
# yes    18
# Name: dispensing, dtype: int64
# drive_through
# no     35
# yes    17
# Name: drive_through, dtype: int64
# wikipedia:fr
# Maison William-Notman            2
# Bibliothèque Mordecai-Richler    2
# Place Versailles                 2
# Dunn's Famous                    1
# Schwartz's                       1
# Fonderie Darling                 1
# Name: wikipedia:fr, dtype: int64
# door
# hinged    1
# Name: door, dtype: int64
# email
# info@globecar.ca                 7
# info@mouvementhumain.com         2
# Kirkland@novusglass.ca           2
# info@cvlaval.com                 2
# info@cafemyriade.com             2
#                                 ..
# info@cafevito.ca                 1
# info@invitationv.com             1
# ComptantOntario1234@gmail.com    1
# info@consulatdumaroc.ca          1
# charles@vayssie.com              1
# Name: email, Length: 97, dtype: int64
# entrance
# yes          3
# secondary    2
# Name: entrance, dtype: int64
# automatic_door
# no    5
# Name: automatic_door, dtype: int64
# takeaway
# yes    147
# no       3
# Name: takeaway, dtype: int64
# outdoor_seating
# yes       55
# no        24
# summer     1
# Name: outdoor_seating, dtype: int64
# level
# 0           131
# 1            18
# -1           10
# 2             2
# 5             2
# Sous-sol      1
# 3             1
# 8             1
# Name: level, dtype: int64
# name:fr
# Banque Nationale                     3
# Musée d'archéologie de Roussillon    2
# centre eaton                         2
# Bijouterie Olivine                   2
# Patinoire hivernale                  2
#                                     ..
# Brochu Mechanique                    1
# Bibliothèque Webster                 1
# Moustache Café                       1
# Charles Vayssié                      1
# ma bicyclette                        1
# Name: name:fr, Length: 116, dtype: int64
# alt_name
# Home Depot                                 5
# La Maison Simons                           4
# SQDC                                       2
# Costco Wholesale Boucherville QC           2
# Caisse Desjardins                          1
# Brasseurs de quartier                      1
# BMO                                        1
# Universal Meat Market Inc/L'intermarché    1
# X20                                        1
# BMO Bank of Montréal                       1
# Café de quartier                           1
# IGA Place Alexis Nihon                     1
# Café Olimpico                              1
# Kentucky Fried Chicken                     1
# Name: alt_name, dtype: int64
# addr:door
# 30     1
# 308    1
# 10     1
# 33B    1
# Name: addr:door, dtype: int64
# payment:cash
# yes     66
# only     1
# Name: payment:cash, dtype: int64
# toilets:wheelchair
# yes    14
# no      7
# Name: toilets:wheelchair, dtype: int64
# payment:debit_cards
# yes    63
# Name: payment:debit_cards, dtype: int64
# payment:credit_cards
# yes    57
# Name: payment:credit_cards, dtype: int64
# internet_access:operator
# Île Sans Fil                               16
# ZAP Montérégie                              1
# Île Sans Fil - http:/www.ilesansfil.org     1
# Name: internet_access:operator, dtype: int64
# delivery
# yes    36
# no     24
# Name: delivery, dtype: int64
# brand:en
# National Bank    3
# Name: brand:en, dtype: int64
# brand:fr
# Banque Nationale    3
# Name: brand:fr, dtype: int64
# official_name
# Bank of Montreal               6
# National Bank of Canada        3
# Royal Bank of Canada           3
# Starbucks Coffee               2
# Five Guys Burgers and Fries    1
# Enterprise Rent-A-Car          1
# Name: official_name, dtype: int64
# official_name:en
# National Bank of Canada    3
# Name: official_name:en, dtype: int64
# official_name:fr
# Banque Nationale du Canada    3
# Name: official_name:fr, dtype: int64
# source
# survey                                                                                                              46
# local_knowledge                                                                                                     13
# CanVec_Import_2009                                                                                                  13
# NRCan-CanVec-10.0                                                                                                   10
# website                                                                                                              3
# survey;Bing 2012                                                                                                     2
# bing                                                                                                                 2
# http://ville.montreal.qc.ca/portal/page?_pageid=4276,5623059&_dad=portal&_schema=PORTAL&section=accueil&lieu=438     2
# NRCan-CanVec-7.0                                                                                                     2
# local_knowledge; survey                                                                                              2
# employee working there                                                                                               1
# survey, receipt                                                                                                      1
# survey & business card                                                                                               1
# Survey                                                                                                               1
# witness location;local knowledge                                                                                     1
# http://www.aceazores.com/Contact-us.php                                                                              1
# https://www.facebook.com/loupgaroumtl/info?tab=page_info                                                             1
# 514gt.com                                                                                                            1
# https://www.facebook.com/lepecheglace/info?tab=page_info                                                             1
# Situé près de chez moi                                                                                               1
# Roger la Roche                                                                                                       1
# Local knowledge                                                                                                      1
# Local_knowledge                                                                                                      1
# http://www.touski.org/                                                                                               1
# NRCan-CanVec-10.0;https://cafedelaroche.business.site                                                                1
# Globecar.com;https://www.globecar.com/en/location/canada/quebec/montreal/outremont-hec-university/                   1
# local knowledge                                                                                                      1
# survey, biz card                                                                                                     1
# survey, business card                                                                                                1
# http://www.timhortons.com/ca/en/locations/get-directions.php?id=103967                                               1
# Name: source, dtype: int64
# healthcare
# pharmacy           42
# dentist             4
# clinic              4
# alternative         2
# physiotherapist     2
# centre              2
# hospital            1
# Name: healthcare, dtype: int64
# leisure
# park              34
# fitness_centre    11
# sports_centre      9
# ice_rink           4
# garden             2
# picnic_table       2
# tanning_salon      2
# hackerspace        2
# playground         2
# dog_park           2
# bowling_alley      2
# sauna              1
# dance              1
# horse_riding       1
# Name: leisure, dtype: int64
# organic
# yes     11
# only     7
# Name: organic, dtype: int64
# contact:email
# sac.web@simons.ca                4
# admin@cafeeclair.com             2
# quinn@montrealkenjutsu.ca        1
# dira@riseup.net                  1
# librairie_insoumise@yahoo.ca     1
# info@rivesud.mercedes-benz.ca    1
# montreal@honorary.mzv.cz         1
# stlaurent@artemano.ca            1
# info@3piliers.ca                 1
# Name: contact:email, dtype: int64
# contact:phone
# (514) 481-7007      2
# +1-450-471-8641     2
# +1 514 495 7880     2
# +1-514-872-4214     2
# +1-514-620-1560     2
# +1-514-598-5946     2
# +1-450-984-8814     2
# +1-514-845-5200     1
# +1-514-684-4900     1
# +1-514-225-0633     1
# +1-514-903-1005     1
# +1-514-843-4420     1
# +1-514-483-1840     1
# +1-514-999-3234     1
# +1-514-626-6933     1
# +1-514-356-1840     1
# +1-514-656-0935     1
# +1-514-277-3407     1
# (514) 557-3006      1
# +1 514 312 2221     1
# +1-514-484-1840     1
# +1-514-667-5934     1
# +1-514-521-0660     1
# +1-514-872-2398     1
# +1-514-563-1204     1
# +1-514-726-1163     1
# +1-438-381-3289     1
# +1-514-487-1411     1
# +1-514-523-3670     1
# +1-514-289-1840     1
# 001-514-316-4383    1
# +1-514-528-1567     1
# +1-514-528-7295     1
# +1-514-528-6361     1
# +1-514-525-2882     1
# Name: contact:phone, dtype: int64
# contact:website
# http://www.weblocal.ca/intermarche-boyer-plateau                                                                           2
# http://www.tonicbar.ca/en/                                                                                                 2
# sqdc.ca/fr-ca/magasins/s-brossard/77020                                                                                    2
# http://www.boucherieatlantique.ca                                                                                          1
# http://montrealpoutine.ca                                                                                                  1
# http://www.3piliers.ca/                                                                                                    1
# http://www.alimentsmerci.com                                                                                               1
# https://laportelogique.com/                                                                                                1
# simons.ca/fr/magasins/quebec/montreal-centre-ville--a13199?utm_source=Other&utm_medium=LPM&utm_campaign=LaMaisonSimons     1
# http://www.stationinvivo.coop/                                                                                             1
# simons.ca/fr/magasins/quebec/promenades-saint-bruno--a13201?utm_source=Other&utm_medium=LPM&utm_campaign=LaMaisonSimons    1
# http://ville.montreal.qc.ca/portal/page?_pageid=4276,5623059&_dad=portal&_schema=PORTAL&section=accueil&lieu=35            1
# http://www.jeancoutu.com/localisateur/detail/5820-avenue-de-Monkland/Montreal/QC/H4A1G1/256/                               1
# http://www.kegsteakhouse.com/en/locations/qc/montreal/place-ville-marie-keg/                                               1
# http://montrealkenjutsu.ca/                                                                                                1
# simons.ca/fr/magasins/quebec/galeries-d-anjou--a13348?utm_source=Other&utm_medium=LPM&utm_campaign=LaMaisonSimons          1
# http://www.goantidote.com/                                                                                                 1
# http://galanga.ca/                                                                                                         1
# simons.ca/fr/magasins/quebec/carrefour-laval--a13200?utm_source=Other&utm_medium=LPM&utm_campaign=LaMaisonSimons           1
# https://514gt.com                                                                                                          1
# http://avocatfisc.com                                                                                                      1
# Name: contact:website, dtype: int64
# payment:visa
# yes    34
# Name: payment:visa, dtype: int64
# payment:interac
# yes    12
# Name: payment:interac, dtype: int64
# payment:mastercard
# yes    30
# Name: payment:mastercard, dtype: int64
# payment:american_express
# yes    5
# Name: payment:american_express, dtype: int64
# ele
# 47.0    2
# 2       2
# 29.0    1
# 0       1
# 46.0    1
# Name: ele, dtype: int64
# addr:country
# CA    23
# Name: addr:country, dtype: int64
# note
# bicycle_repair_station (no rental)                                                                                                                                                                                                               10
# archeology preserved in connected tunnel.                                                                                                                                                                                                         2
# Heures d'ouvertures du dimanche sont compliquées, car fermés les dimanches l'été et possiblement durant Covid-19                                                                                                                                  2
# Table à pique-nique pour se reposer lors d’une expédition dans le refuge faunique de la Rivière-des-Milles-Îles                                                                                                                                   2
# appliance,appliance parts supplier,appliance shop,appliance store,home furnishings,furniture,mattresses                                                                                                                                           1
# Underground charging station, access from underground parking entrance                                                                                                                                                                            1
# Bitcoin ATM in La Belle Province.                                                                                                                                                                                                                 1
# frozen food                                                                                                                                                                                                                                       1
# Service de casiers d’entreposage, service de cases postales, immeubles à logements sociaux, service de retour à l’emploi, ateliers divers, activités de financement, programme de réinsertion sociale et économique, et autres.                   1
# reparation ordinateur virus                                                                                                                                                                                                                       1
# Chemin de la Cote-Sainte-Catherine                                                                                                                                                                                                                1
# Vendredi et samedi , ferme jusqu'à 3h du matin                                                                                                                                                                                                    1
# Bravo Telecom is located in Montreal to provide all Quebec residents best affordable packages for both telephone and internet. As an internet provider (ISP), Bravo Telecom addresses the needs of all households according to their budgets.     1
# organic fair-trade eco local grocery store and cafe                                                                                                                                                                                               1
# Ancienne cheminée restorée permettant d’être utilisée comme abri par le Martinet Ramoneur, espèce en voie d’extinction                                                                                                                            1
# Bronzage                                                                                                                                                                                                                                          1
# Metro Level                                                                                                                                                                                                                                       1
# building:level=3                                                                                                                                                                                                                                  1
# Montreal University                                                                                                                                                                                                                               1
# mostly oriented towards maps and geography, a major reference in montreal. one of the few points where topographic maps are sold in montreal.                                                                                                     1
# sells only fruit and vegetables                                                                                                                                                                                                                   1
# Name: note, dtype: int64
# contact:twitter
# https://twitter.com/SIMONS        4
# https://twitter.com/La_SQDC       2
# montrealpoutine                   1
# https://twitter.com/JacopAutos    1
# Name: contact:twitter, dtype: int64
# payment:bitcoin
# yes    13
# Name: payment:bitcoin, dtype: int64
# contact:facebook
# facebook.com/simons.ca/                                           4
# https://www.facebook.com/eclair.montreal/                         2
# facebook.com/lasqdc/                                              2
# https://www.facebook.com/goantidote                               1
# https://www.facebook.com/montrealkenjutsu                         1
# https://www.facebook.com/pages/Hamel-Martine/820017864808226      1
# https://www.facebook.com/chezdallaire                             1
# https://www.facebook.com/pages/Station-W/154300254764417          1
# https://www.facebook.com/JacopAutos/                              1
# https://www.facebook.com/Sonik-Records-186553604713275/           1
# https://www.facebook.com/poubelleduski/                           1
# https://www.facebook.com/LeToasteurVilleray                       1
# https://www.facebook.com/decathloncentreeaton                     1
# https://www.facebook.com/PatisserieRaffin/                        1
# https://www.facebook.com/Boucherie-Atlantique-257242954327555/    1
# https://www.facebook.com/MontrealPoutine                          1
# Name: contact:facebook, dtype: int64
# internet_access:ssid
# MTLWiFi       2
# BMOguest      1
# mpoutine      1
# MtlWifi       1
# Bato Thai     1
# atomic neu    1
# Name: internet_access:ssid, dtype: int64
# description
# Pizzeria familiale.                                                                                                                               2
# Services vétérinaires d'urgences et spécialités                                                                                                   2
# Cash at ATM only!!! (the cashiers do NOT handle any money).                                                                                       2
# Centre de services Domaine Saint-Sulpice                                                                                                          2
# Services vétérinaire d'urgence et spécialité                                                                                                      2
#                                                                                                                                                  ..
# Bouffe simple et rapide.                                                                                                                          1
# Trust the experts at B&H Inc. for your landscaping and snow removal needs.                                                                        1
# Plats à emporter chauds et froids pour vos lunchs et soupers. Possibilité d'apporter ses propres contenants.                                      1
# Boutique spécialisée en accessoires pour allaitement et autres produits pour bébés.                                                               1
# Que vous ayez besoin d’un simple examen de routine ou d’un traitement de canal, les dentistes du Centre Dentaire de Brossard vous accueillent.    1
# Name: description, Length: 82, dtype: int64
# office
# government              24
# company                  7
# employment_agency        3
# lawyer                   3
# coworking                3
# research                 3
# diplomatic               3
# notary                   3
# architect                2
# tax_advisor              2
# association              2
# construction_company     1
# advertising_agency       1
# ngo                      1
# credit_bureau            1
# Suite 203                1
# it                       1
# estate_agent             1
# accountant               1
# surveyor                 1
# administrative           1
# Name: office, dtype: int64
# country
# MA    1
# CZ    1
# DE    1
# Name: country, dtype: int64
# name:de
# Service Canada Center                             1
# Bixi                                              1
# Plazatex Inc                                      1
# Mauve professionelle Piercings                    1
# Steve's Musikladen                                1
# H. Fisher und Fils Zubehör für Schneider          1
# Generalkonsulat der Bundesrepublik Deutschland    1
# Name: name:de, dtype: int64
# addr:unit
# 300                       4
# 500                       4
# 101                       2
# 204                       1
# 312A                      1
# 306                       1
# #16-30                    1
# 106                       1
# Local 30                  1
# C-022A                    1
# 110                       1
# DE-R200                   1
# 850                       1
# US Departures (Door 7)    1
# 2001                      1
# 301                       1
# 402                       1
# Espace 106                1
# Cafeteria                 1
# 4315                      1
# 194                       1
# 303                       1
# 100                       1
# Suite 260                 1
# 206                       1
# 201                       1
# B                         1
# Name: addr:unit, dtype: int64
# consulate
# consulate_general    2
# Name: consulate, dtype: int64
# diplomatic
# consulate             2
# honorary_consulate    1
# Name: diplomatic, dtype: int64
# opening_hours:covid19
# off                  6
# same                 4
# open                 2
# restricted           2
# Th-Su 10:00-17:00    1
# closed               1
# Name: opening_hours:covid19, dtype: int64
# air_conditioning
# yes    6
# Name: air_conditioning, dtype: int64
# gst_number
# 867177792    1
# Name: gst_number, dtype: int64
# qst_number
# 1021398566    1
# Name: qst_number, dtype: int64
# store_name
# Micro-Bytes Centre-Ville    1
# Name: store_name, dtype: int64
# company_name
# 3477355 Canada Inc.    1
# Name: company_name, dtype: int64
# contact:youtube
# youtube.com/user/simons    4
# Name: contact:youtube, dtype: int64
# contact:linkedin
# linkedin.com/company/la-maison-simons    4
# linkedin.com/company/sqdc/               2
# Name: contact:linkedin, dtype: int64
# contact:instagram
# instagram.com/maisonsimons/                        4
# https://www.instagram.com/eclair.montreal/         2
# https://www.instagram.com/jacop_autos/?hl=en       1
# https://www.instagram.com/goantidote/              1
# https://www.instagram.com/hyosetsudojomontreal/    1
# https://instagram.com/la_grange_du_boulanger/      1
# Name: contact:instagram, dtype: int64
# diet:vegan
# yes        10
# only        5
# no          3
# limited     2
# Name: diet:vegan, dtype: int64
# diet:vegetarian
# yes        20
# limited     2
# only        1
# Name: diet:vegetarian, dtype: int64
# clothes
# women              6
# men;women          3
# underwear          3
# underwear;women    1
# Name: clothes, dtype: int64
# brewery
# yes                          4
# various                      1
# Jukebox;Ippon;Avant-Garde    1
# Name: brewery, dtype: int64
# diesel
# yes    1
# Name: diesel, dtype: int64
# service:bicycle:pump
# yes    17
# Name: service:bicycle:pump, dtype: int64
# service:bicycle:rental
# yes    3
# Name: service:bicycle:rental, dtype: int64
# service:bicycle:repair
# yes    9
# Name: service:bicycle:repair, dtype: int64
# service:bicycle:retail
# yes    5
# Name: service:bicycle:retail, dtype: int64
# second_hand
# yes     6
# only    5
# no      3
# Name: second_hand, dtype: int64
# addr:housename
# Maison Notman                 2
# AEELI                         2
# Le port de tête               1
# Café Larue & fils             1
# Eaton Centre                  1
# Fruiterie Papaye Et Mangue    1
# Name: addr:housename, dtype: int64
# sport
# climbing                                          3
# skating;hockey                                    2
# billiards                                         2
# 10pin                                             2
# yoga;pilates;essentrics                           2
# Skating, Hockey, Basketball                       2
# All                                               1
# karate;boxing;kickboxing;exercise;martial_arts    1
# Kenjutsu                                          1
# kendo                                             1
# Name: sport, dtype: int64
# addr:street:en
# Ontario Street East    1
# Name: addr:street:en, dtype: int64
# service_times
# Mo-Fr 07:30-17:30    1
# Name: service_times, dtype: int64
# payment:coins
# yes    10
# no      3
# Name: payment:coins, dtype: int64
# microbrewery
# yes    6
# no     1
# Name: microbrewery, dtype: int64
# service:bicycle:diy
# yes    3
# Name: service:bicycle:diy, dtype: int64
# comment
# Wednesday is "women-trans-femme only"    1
# Name: comment, dtype: int64
# created_by
# iLOE 1.9    2
# Name: created_by, dtype: int64
# building:levels
# 1      6
# 3      4
# 0      3
# 2.5    2
# 5      2
# 7      2
# Name: building:levels, dtype: int64
# bicycle_parking
# stands    1
# Name: bicycle_parking, dtype: int64
# male
# yes    4
# no     2
# Name: male, dtype: int64
# female
# no     3
# yes    2
# Name: female, dtype: int64
# drinking_water
# yes    1
# Name: drinking_water, dtype: int64
# image
# File:Parc de Dieppe, panneau d'accueil.jpg                                                                                  2
# http://www.britandchips.com/english/wp-content/uploads/2012/07/britpic1_lg2.jpeg                                            1
# http://www.shaktirockgym.com/wp-content/uploads/2012/ftp/IMG_0001.jpg                                                       1
# https://commons.wikimedia.org/wiki/File:L%27Insoumise_Montreal.jpg                                                          1
# https://img1.wsimg.com/isteam/ip/0e495d70-26e4-4e6d-b068-9fd432b6d23a/24955374_1493593160748698_7203112016098060698_.png    1
# http://www.restoindiasoven.com/images/8.jpg                                                                                 1
# Name: image, dtype: int64
# building
# yes                212
# retail              40
# roof                10
# commercial           8
# civic                6
# public               6
# public_building      2
# farm_auxiliary       2
# library              2
# garage               2
# university           2
# residential          2
# hotel                2
# office               1
# warehouse            1
# Name: building, dtype: int64
# leisure_1
# sports_centre    1
# Name: leisure_1, dtype: int64
# climbing:boulder
# yes    1
# Name: climbing:boulder, dtype: int64
# min_age
# 18    1
# Name: min_age, dtype: int64
# food
# no            1
# sandwiches    1
# yes           1
# Name: food, dtype: int64
# social_facility
# nursing_home       2
# outreach           1
# ambulatory_care    1
# Name: social_facility, dtype: int64
# beer_garden
# yes    1
# Name: beer_garden, dtype: int64
# emergency
# no               2
# yes              2
# defibrillator    1
# Name: emergency, dtype: int64
# fee
# yes              7
# no               2
# 7,50$ one way    1
# Name: fee, dtype: int64
# parking
# surface         4
# multi-storey    2
# underground     1
# Name: parking, dtype: int64
# fax
# +1-514-697-6461    2
# 514-505-6670       2
# +1-514-352-3519    2
# 514-505-6671       2
# +1 514-733-7788    2
# +1-450-625-8495    2
# +1-514-764-1957    1
# +1-450-688-8860    1
# +1-514-948-5253    1
# 514-733-7788       1
# (514) 345-1088     1
# +1-514-280-0623    1
# +1-514-525-2760    1
# +1 514-288-4859    1
# 514-642-4099       1
# 1-888-767-6859     1
# +1-514-874-0251    1
# +1 450-659-3090    1
# (450) 975-8696     1
# +1514 526 4498     1
# +1-514-933-4203    1
# +1-514-725-0152    1
# (514) 733-7788     1
# +1-514-522-8108    1
# +1 514 903 1795    1
# +1514-524-3443     1
# +1 514-352-1381    1
# Name: fax, dtype: int64
# drive_in
# no    1
# Name: drive_in, dtype: int64
# wifi
# yes    3
# no     1
# Name: wifi, dtype: int64
# old_name
# Laurentian Bank                             2
# CLSC de Pointe-Aux-Trembles-Montréal-Est    1
# Café-Bar de la Cinémathèque québécoise      1
# Les urbainculteurs                          1
# Name: old_name, dtype: int64
# amenity_1
# cafe           3
# post_office    1
# restaurant     1
# Name: amenity_1, dtype: int64
# furniture
# stuffing    1
# Name: furniture, dtype: int64
# branch
# Monkland                 2
# N.D.G. - Rue Monkland    1
# Monkland et Harvard      1
# Notre-Dame-de-Grâce      1
# Name: branch, dtype: int64
# short_name
# Costco       2
# SAQ          2
# MAC          2
# RBC          1
# S64B Inc.    1
# MEC          1
# Name: short_name, dtype: int64
# craft
# tailor                4
# shoemaker             4
# electronics_repair    3
# brewery               2
# electrician           1
# construction          1
# sign_maker            1
# gardener              1
# optician              1
# mason                 1
# floorer               1
# locksmith             1
# caterer               1
# handicraft            1
# Name: craft, dtype: int64
# terrasse
# hors rue bétonné hors du trottoir sur le terrain    1
# Name: terrasse, dtype: int64
# unisex
# yes    6
# no     4
# Name: unisex, dtype: int64
# internet_access:type
# wlan    1
# Name: internet_access:type, dtype: int64
# toilets
# yes    13
# no      2
# Name: toilets, dtype: int64
# cocktails
# yes       3
# served    1
# Name: cocktails, dtype: int64
# drink:tea
# yes    2
# Name: drink:tea, dtype: int64
# drink:beer
# served    4
# yes       4
# Name: drink:beer, dtype: int64
# drink:wine
# yes       5
# served    2
# Name: drink:wine, dtype: int64
# drink:coffee
# yes       3
# served    1
# Name: drink:coffee, dtype: int64
# toilets:unisex
# no     4
# yes    2
# Name: toilets:unisex, dtype: int64
# payment:contactless
# yes    6
# Name: payment:contactless, dtype: int64
# social_facility:for
# senior           2
# drug_addicted    1
# migrant          1
# Name: social_facility:for, dtype: int64
# books
# comic        2
# anarchism    2
# maps         1
# Name: books, dtype: int64
# start_date
# 1986          2
# 1996-04-01    1
# 2017-12-08    1
# 1988          1
# 1999          1
# 2019-07-13    1
# 2004-11-13    1
# 2018          1
# 2005          1
# 2006          1
# Name: start_date, dtype: int64
# operator:type
# community    2
# public       1
# Name: operator:type, dtype: int64
# store_ref
# 8253    1
# Name: store_ref, dtype: int64
# self_checkout
# yes    1
# Name: self_checkout, dtype: int64
# wheelchair:description
# StopGap ramp    1
# Name: wheelchair:description, dtype: int64
# repair
# yes    3
# Name: repair, dtype: int64
# recycling_type
# centre    3
# Name: recycling_type, dtype: int64
# recycling:computers
# yes    1
# Name: recycling:computers, dtype: int64
# opening_hours:kitchen
# Mo-We 11:30-15:00,17:30-23:00; Th,Fr 11:30-15:00,17:30-00:00; Sa 17:00-00:00; Su 17:30-23:00    1
# Mo 08:00-15:00; Tu-Fr 08:00-17:30; Sa,Su 09:00-15:00                                            1
# Name: opening_hours:kitchen, dtype: int64
# currency:AUD
# yes    1
# Name: currency:AUD, dtype: int64
# currency:CAD
# yes    7
# Name: currency:CAD, dtype: int64
# currency:CHF
# yes    1
# Name: currency:CHF, dtype: int64
# currency:CNY
# yes    1
# Name: currency:CNY, dtype: int64
# currency:EUR
# yes    2
# Name: currency:EUR, dtype: int64
# currency:GBP
# yes    2
# Name: currency:GBP, dtype: int64
# currency:JPY
# yes    1
# Name: currency:JPY, dtype: int64
# currency:MXN
# yes    1
# Name: currency:MXN, dtype: int64
# currency:USD
# yes    2
# Name: currency:USD, dtype: int64
# currency:XBT
# yes    7
# Name: currency:XBT, dtype: int64
# contact:fax
# +1-888-210-4594    2
# Name: contact:fax, dtype: int64
# cargo
# passengers    1
# Name: cargo, dtype: int64
# step_count
# 3    1
# Name: step_count, dtype: int64
# automatic door
# no    1
# Name: automatic door, dtype: int64
# topic
# learning_opportunities    1
# Name: topic, dtype: int64
# identity
# solidarity_economy    1
# Name: identity, dtype: int64
# provides
# objects_of_utility    1
# Name: provides, dtype: int64
# interaction
# cousing    1
# Name: interaction, dtype: int64
# fuel:gasoline
# yes    2
# Name: fuel:gasoline, dtype: int64
# service:copy
# yes    1
# Name: service:copy, dtype: int64
# service:press
# yes    1
# Name: service:press, dtype: int64
# service:prepress
# yes    1
# Name: service:prepress, dtype: int64
# facebook
# www.facebook.com/rrarchitectes/                 1
# bibliolgbtqplus                                 1
# cclgbtqplus                                     1
# https://www.facebook.com/kendoayame/            1
# https://www.facebook.com/lagrangeduboulanger    1
# Name: facebook, dtype: int64
# pastry_shop
# yes    1
# Name: pastry_shop, dtype: int64
# access
# yes           7
# permissive    2
# foot          1
# customers     1
# Name: access, dtype: int64
# access:conditional
# no@winter    1
# no@summer    1
# Name: access:conditional, dtype: int64
# foot
# yes    1
# Name: foot, dtype: int64
# motor_vehicle
# yes    1
# Name: motor_vehicle, dtype: int64
# diaper
# yes    1
# Name: diaper, dtype: int64
# toilets:access
# permissive    2
# customers     1
# Name: toilets:access, dtype: int64
# opening_hours_1
# Week end 9:00-22:00    1
# Name: opening_hours_1, dtype: int64
# opening_hours:url
# https://www.vaporus.com/stores                                                               2
# http://www.banq.qc.ca/a_propos_banq/informations_pratiques/grande_bibliotheque/index.html    2
# https://www.polymtl.ca/biblio/en/hours                                                       1
# Name: opening_hours:url, dtype: int64
# indoor
# room    6
# area    2
# yes     1
# Name: indoor, dtype: int64
# theme
# irish    1
# Name: theme, dtype: int64
# reservation
# yes            2
# recommended    1
# required       1
# Name: reservation, dtype: int64
# authentication:membership_card
# yes    5
# Name: authentication:membership_card, dtype: int64
# position
# approximative    2
# aproximative     1
# Name: position, dtype: int64
# internet
# wlan    1
# Name: internet, dtype: int64
# addr:number
# 3950    1
# Name: addr:number, dtype: int64
# payment:notes
# no     3
# yes    2
# Name: payment:notes, dtype: int64
# not:name
# Cycle_Campus_Verdun    1
# Name: not:name, dtype: int64
# service:bicycle:bike
# yes    3
# Name: service:bicycle:bike, dtype: int64
# service:bicycle:bike_tools
# yes    1
# Name: service:bicycle:bike_tools, dtype: int64
# wlan
# yes    1
# Name: wlan, dtype: int64
# lottery
# yes    2
# Name: lottery, dtype: int64
# service:scan
# yes    1
# Name: service:scan, dtype: int64
# service:print
# yes    1
# Name: service:print, dtype: int64
# healthcare:speciality
# general                                                         2
# dentist                                                         1
# general;community;dermatology;urology;vaccination;psychiatry    1
# Name: healthcare:speciality, dtype: int64
# name:ru
# Международная почтовая служба    1
# Вестерн Юнион                    1
# Name: name:ru, dtype: int64
# beauty
# nails       9
# tanning     3
# supplies    1
# Name: beauty, dtype: int64
# payment:discover_card
# yes    1
# Name: payment:discover_card, dtype: int64
# dog
# no         3
# leashed    2
# Allowed    2
# Name: dog, dtype: int64
# addr:streetnumber
# 4050    1
# 4030    1
# Name: addr:streetnumber, dtype: int64
# payment:cheque
# yes    2
# Name: payment:cheque, dtype: int64
# payment
# cash, debit, credit, paypass,Argent comptant, Carte de crédit, Carte de débit    1
# Name: payment, dtype: int64
# phone:tollfree
# +1-866-972-2173    1
# +1-800-604-1096    1
# Name: phone:tollfree, dtype: int64
# service:bicycle:tools
# yes    7
# Name: service:bicycle:tools, dtype: int64
# lgbtq
# primary    2
# Name: lgbtq, dtype: int64
# community_centre:for
# lgbtq    1
# Name: community_centre:for, dtype: int64
# ruins
# chimney    1
# Name: ruins, dtype: int64
# historic
# castle      2
# monument    2
# ruins       1
# Name: historic, dtype: int64
# man_made
# quay       3
# chimney    1
# Name: man_made, dtype: int64
# material
# wood    1
# Name: material, dtype: int64
# self_service
# yes    4
# Name: self_service, dtype: int64
# target
# CA    1
# Name: target, dtype: int64
# name:cs
# Honorární konzulát České republiky    1
# Name: name:cs, dtype: int64
# fuel:diesel
# yes    4
# Name: fuel:diesel, dtype: int64
# beer
# served    1
# Name: beer, dtype: int64
# coffee
# yes    1
# Name: coffee, dtype: int64
# fuel:octane_87
# yes    3
# Name: fuel:octane_87, dtype: int64
# fuel:octane_95
# yes    3
# Name: fuel:octane_95, dtype: int64
# service:vehicle:glass
# yes    5
# Name: service:vehicle:glass, dtype: int64
# service:vehicle:car_repair
# yes    5
# Name: service:vehicle:car_repair, dtype: int64
# service:vehicle:windshield
# yes    3
# Name: service:vehicle:windshield, dtype: int64
# sport_1
# Iaijutsu    1
# Name: sport_1, dtype: int64
# sport_2
# Naginatajutsu    1
# Name: sport_2, dtype: int64
# sport_3
# Jojutsu    1
# Name: sport_3, dtype: int64
# sport_4
# Jujutsu    1
# Name: sport_4, dtype: int64
# sport_5
# Tantojutsu    1
# Name: sport_5, dtype: int64
# contact:person
# Kurenda Sensei (Quinn Kurenda)    1
# Name: contact:person, dtype: int64
# name:ja
# プロント    1
# Name: name:ja, dtype: int64
# addr:state
# CA    1
# QC    1
# Name: addr:state, dtype: int64
# ramp:wheelchair
# no    4
# Name: ramp:wheelchair, dtype: int64
# diet:gluten_free
# yes    1
# Name: diet:gluten_free, dtype: int64
# payment:credit_card
# yes    1
# Name: payment:credit_card, dtype: int64
# payment:all
# yes    1
# Name: payment:all, dtype: int64
# bar
# no    1
# Name: bar, dtype: int64
# diet:meat
# yes    1
# Name: diet:meat, dtype: int64
# cash_in
# yes    5
# Name: cash_in, dtype: int64
# cash_out
# yes    4
# Name: cash_out, dtype: int64
# name:zh
# 新起点学院    1
# Name: name:zh, dtype: int64
# language:en
# yes    1
# Name: language:en, dtype: int64
# language:es
# yes    1
# Name: language:es, dtype: int64
# language:fr
# yes    1
# Name: language:fr, dtype: int64
# language:ja
# yes    1
# Name: language:ja, dtype: int64
# language:ko
# yes    1
# Name: language:ko, dtype: int64
# language:ru
# yes    1
# Name: language:ru, dtype: int64
# language:zh
# yes    1
# Name: language:zh, dtype: int64
# service:bicycle:parts
# yes    1
# Name: service:bicycle:parts, dtype: int64
# service:bicycle:service
# yes    1
# Name: service:bicycle:service, dtype: int64
# service:bicycle:second_hand
# yes    1
# Name: service:bicycle:second_hand, dtype: int64
# scooter:sales
# yes    1
# Name: scooter:sales, dtype: int64
# scooter:rental
# yes    1
# Name: scooter:rental, dtype: int64
# service:bicycle:Bicycle_Sales_and_Service
# yes    1
# Name: service:bicycle:Bicycle_Sales_and_Service, dtype: int64
# animal_boarding
# dog    1
# Name: animal_boarding, dtype: int64
# telephone
# 514-647-2143    1
# Name: telephone, dtype: int64
# car
# yes    1
# Name: car, dtype: int64
# voltage
# 400    1
# Name: voltage, dtype: int64
# amperage
# 125    1
# Name: amperage, dtype: int64
# parking:fee
# no    1
# Name: parking:fee, dtype: int64
# socket:chademo
# 2    1
# Name: socket:chademo, dtype: int64
# socket:type1_combo
# 2    1
# Name: socket:type1_combo, dtype: int64
# languages
# Français, English    1
# Name: languages, dtype: int64
# bic
# BOFMCAM2    1
# Name: bic, dtype: int64
# service:bicycle:fitting
# yes    1
# Name: service:bicycle:fitting, dtype: int64
# surface
# asphalt    4
# grass      2
# wood       1
# Name: surface, dtype: int64
# cash_withdrawal
# No    1
# Name: cash_withdrawal, dtype: int64
# operator:wikidata
# Q483551    1
# Name: operator:wikidata, dtype: int64
# operator:wikipedia
# en:Walmart    1
# Name: operator:wikipedia, dtype: int64
# ref:isil
# QMBN    2
# Name: ref:isil, dtype: int64
# name:formal
# Grande Bibliothèque    2
# Name: name:formal, dtype: int64
# building:material
# glass    2
# Name: building:material, dtype: int64
# building:levels:underground
# 3    2
# Name: building:levels:underground, dtype: int64
# loc_name
# Costco               2
# Costco rue Bridge    2
# Name: loc_name, dtype: int64
# membership
# yes    6
# Name: membership, dtype: int64
# attribution
# Natural Resources Canada    12
# Name: attribution, dtype: int64
# canvec:CODE
# 2010252    6
# 2010382    2
# Name: canvec:CODE, dtype: int64
# roof:levels
# 0    2
# Name: roof:levels, dtype: int64
# name:ko
# 봉스쿠르마켓    2
# 람제이성      2
# Name: name:ko, dtype: int64
# museum
# history    4
# Name: museum, dtype: int64
# castle_type
# stately    2
# Name: castle_type, dtype: int64
# contact:yelp
# https://www.yelp.com/biz/parc-de-la-cité-du-havre-montréal    2
# Name: contact:yelp, dtype: int64
# wikimedia_commons
# Category:Parc de Dieppe    2
# Name: wikimedia_commons, dtype: int64
# contact:foursquare
# https://www.foursquare.com/v/4ad4c06cf964a520e2f920e3    2
# Name: contact:foursquare, dtype: int64
# name:etymology:wikidata
# Q270517    2
# Name: name:etymology:wikidata, dtype: int64
# old_name:1992-01-24-2017-08-31
# Parc de la Cité-du-Havre    2
# Name: old_name:1992-01-24-2017-08-31, dtype: int64
# old_name:en
# Mile-End Library    2
# Name: old_name:en, dtype: int64
# old_name:fr
# Bibliothèque Mile-End    2
# Name: old_name:fr, dtype: int64
# nam:en
# du Parc YMCA    2
# Name: nam:en, dtype: int64
# bicycle
# dismount    2
# Name: bicycle, dtype: int64
# kids_area
# indoor    2
# Name: kids_area, dtype: int64
# fuel:octane_91
# yes    2
# Name: fuel:octane_91, dtype: int64
# source:name
# common knowledge    2
# Name: source:name, dtype: int64
# source:position
# common knowledge    2
# Name: source:position, dtype: int64
# shop_1
# skate sharpening    2
# Name: shop_1, dtype: int64
# elevator
# yes    2
# Name: elevator, dtype: int64
# payment:cards
# yes    2
# Name: payment:cards, dtype: int64
# payment:visa_debit
# yes    2
# Name: payment:visa_debit, dtype: int64
# service:vehicle:motor
# yes    2
# Name: service:vehicle:motor, dtype: int64
# service:vehicle:tires
# yes    2
# Name: service:vehicle:tires, dtype: int64
# service:vehicle:brakes
# yes    2
# Name: service:vehicle:brakes, dtype: int64
# service:vehicle:wheels
# yes    2
# Name: service:vehicle:wheels, dtype: int64
# service:vehicle:muffler
# yes    2
# Name: service:vehicle:muffler, dtype: int64
# service:vehicle:repairs
# yes    2
# Name: service:vehicle:repairs, dtype: int64
# service:vehicle:batteries
# yes    2
# Name: service:vehicle:batteries, dtype: int64
# service:vehicle:electrical
# yes    2
# Name: service:vehicle:electrical, dtype: int64
# service:vehicle:oil_change
# yes    2
# Name: service:vehicle:oil_change, dtype: int64
# service:vehicle:diagnostics
# yes    2
# Name: service:vehicle:diagnostics, dtype: int64
# service:vehicle:truck_repair
# yes    2
# Name: service:vehicle:truck_repair, dtype: int64
# service:vehicle:air_conditioning
# yes    2
# Name: service:vehicle:air_conditioning, dtype: int64
# service:vehicle:Transmission_Repair
# yes    2
# Name: service:vehicle:Transmission_Repair, dtype: int64
# seasonal
# summer    3
# Yes       2
# yes       2
# Name: seasonal, dtype: int64
# is_in:neighbourhood
# NDG (Notre-Dame-de-Grâce)    2
# Name: is_in:neighbourhood, dtype: int64
# park_ride
# yes    2
# Name: park_ride, dtype: int64
# capacity:disabled
# yes    2
# Name: capacity:disabled, dtype: int64
# place
# farm    2
# Name: place, dtype: int64
# u-pick
# yes    2
# Name: u-pick, dtype: int64
# building:part
# yes    2
# Name: building:part, dtype: int64
# fuel:octane_92
# yes    2
# Name: fuel:octane_92, dtype: int64
# fuel:octane_98
# yes    2
# Name: fuel:octane_98, dtype: int64
# layer
# 1    2
# Name: layer, dtype: int64
# lit
# yes    2
# Name: lit, dtype: int64
# service:vehicle:tyres
# yes    2
# Name: service:vehicle:tyres, dtype: int64
# service:vehicle:suspension
# yes    2
# Name: service:vehicle:suspension, dtype: int64
# playground:theme
# playground    2
# Name: playground:theme, dtype: int64
# geometry
# POINT (-73.570448 45.513086)                                                                                                                                                            1
# POINT (-73.5664072 45.506711)                                                                                                                                                           1
# POINT (-73.58394389999999 45.5242643)                                                                                                                                                   1
# POINT (-73.5676536 45.4579708)                                                                                                                                                          1
# POINT (-73.5704004 45.5371126)                                                                                                                                                          1
#                                                                                                                                                                                        ..
# POINT (-73.57212699999999 45.4557573)                                                                                                                                                   1
# POINT (-73.5449916 45.5450927)                                                                                                                                                          1
# POINT (-73.57925349999999 45.527736)                                                                                                                                                    1
# POINT (-73.6174192 45.5038992)                                                                                                                                                          1
# (POLYGON ((-73.5784223 45.5438316, -73.5778019 45.5436271, -73.5775041 45.5441315, -73.5780755 45.5442939, -73.5782952 45.5439128, -73.5783459 45.5439342, -73.5784223 45.5438316)))    1
# Name: geometry, Length: 2049, dtype: int64

# %%
COLUMNS_TO_USE = ['name','opening_hours','amenity','tourism', 'shop', 'healthcare', 'leisure', 'sport','craft', 'building','geometry']

# %%
all_opening_hours[COLUMNS_TO_USE].to_csv('../Data/model_inputs/mtl_opening_hours_cleaned.csv',index=False, encoding='utf-8')
