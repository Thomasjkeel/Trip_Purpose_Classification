# %%
def get_opening_hours_from_osm_data(path_to_osm_geojson):
    """
        path_to_osm_geojson (geojson): path to the geojson file. We get data from https://download.bbbike.org/osm/bbbike/ 
    """

    f = open(path_to_osm_geojson, "r")
    all_lines = f.readlines()
    print("Number of lines in file:", len(all_lines))

    line_index = 0
    opening_hours_indexes = []
    
    f = open(path_to_osm_geojson, "r")
    for x in f:
        if 'opening_hours' in x:
            opening_hours_indexes.append(line_index)
        line_index += 1
    print("Number of opening_hours entries:", len(opening_hours_indexes))
    return all_lines, opening_hours_indexes


def write_opening_hours_to_geojson(path_to_output_geojson, all_lines, opening_hours_indexes):
    """
        all_lines (list): all lines in the overall file
        
    """
    with open(path_to_output_geojson, "w+") as my_file:
        my_file.write(all_lines[0])
        for line in opening_hours_indexes[:-1]:
            my_file.write(all_lines[line])
        # remove comma from final line
        final_line = all_lines[opening_hours_indexes[-1]].replace(",\n","\n")
        my_file.write(final_line)
        my_file.write(all_lines[-1])
        my_file.close()

# %%
# all_lines, opening_hours_indexes = get_opening_hours_from_osm_data(path_to_osm_geojson="../Data/shapes/Montreal.osm.geojson")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ba4b29651195> in <module>
# ----> 1 all_lines, opening_hours_indexes = get_opening_hours_from_osm_data(path_to_osm_geojson="../Data/shapes/Montreal.osm.geojson")
#
# <ipython-input-1-18b171b17254> in get_opening_hours_from_osm_data(path_to_osm_geojson)
#       4     """
#       5
# ----> 6     f = open(path_to_osm_geojson, "r")
#       7     all_lines = f.readlines()
#       8     print("Number of lines in file:", len(all_lines))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Data/shapes/Montreal.osm.geojson'

# %%
# write_opening_hours_to_geojson(all_lines=all_lines, opening_hours_indexes=opening_hours_indexes, path_to_output_geojson="../Data/model_inputs/mtl_opening_hours.geojson")

# %%
import geopandas as gpd

# %%
all_opening_hours = gpd.read_file("../Data/model_inputs/mtl_opening_hours.geojson")

# %%
all_opening_hours
# Out:
#                         url                              name  \
# 0     http://www.mbam.qc.ca  Musée des Beaux-Arts de Montréal
# 1                      None                      Noodles Star
# 2                      None                              None
# 3                      None                              Maxi
# 4                      None                  Ben & Florentine
# ...                     ...                               ...
# 2044                   None      Boucherie Richard Daigneault
# 2045                   None                       Auto Cougar
# 2046                   None                         Écocentre
# 2047                   None           Parc Du Moulin-Desbiens
# 2048                   None                              None
#
#                 phone                       name:en tourism wikidata  \
# 0     +1 514 285 2000  Montreal Museum of Fine Arts  museum  Q860812
# 1     +1-514-932-2888                          None    None     None
# 2                None                          None    None     None
# 3     +1-450-672-3201                          None    None     None
# 4                None                          None    None     None
# ...               ...                           ...     ...      ...
# 2044             None                          None    None     None
# 2045             None                          None    None     None
# 2046             None                          None    None     None
# 2047             None                          None    None     None
# 2048             None                          None    None     None
#
#                             wikipedia wheelchair          alt_name:en  \
# 0     en:Montreal Museum of Fine Arts        yes  Museum of Fine Arts
# 1                                None    limited                 None
# 2                                None       None                 None
# 3                                None       None                 None
# 4                                None       None                 None
# ...                               ...        ...                  ...
# 2044                             None       None                 None
# 2045                             None       None                 None
# 2046                             None       None                 None
# 2047                             None       None                 None
# 2048                             None       None                 None
#
#                alt_name:fr  ... u-pick building:part fuel:octane_92  \
# 0     Musée des Beaux-Arts  ...   None          None           None
# 1                     None  ...   None          None           None
# 2                     None  ...   None          None           None
# 3                     None  ...   None          None           None
# 4                     None  ...   None          None           None
# ...                    ...  ...    ...           ...            ...
# 2044                  None  ...   None          None           None
# 2045                  None  ...   None          None           None
# 2046                  None  ...   None          None           None
# 2047                  None  ...   None          None           None
# 2048                  None  ...   None          None           None
#
#      fuel:octane_98 layer   lit service:vehicle:tyres  \
# 0              None  None  None                  None
# 1              None  None  None                  None
# 2              None  None  None                  None
# 3              None  None  None                  None
# 4              None  None  None                  None
# ...             ...   ...   ...                   ...
# 2044           None  None  None                  None
# 2045           None  None  None                   yes
# 2046           None  None  None                  None
# 2047           None  None  None                  None
# 2048           None  None  None                  None
#
#      service:vehicle:suspension playground:theme  \
# 0                          None             None
# 1                          None             None
# 2                          None             None
# 3                          None             None
# 4                          None             None
# ...                         ...              ...
# 2044                       None             None
# 2045                        yes             None
# 2046                       None             None
# 2047                       None             None
# 2048                       None       playground
#
#                                                geometry
# 0                            POINT (-73.57940 45.49870)
# 1                            POINT (-73.58042 45.49307)
# 2                            POINT (-73.51726 45.49226)
# 3                            POINT (-73.46781 45.46025)
# 4                            POINT (-73.46731 45.46930)
# ...                                                 ...
# 2044  MULTIPOLYGON (((-73.94132 45.52862, -73.94123 ...
# 2045  MULTIPOLYGON (((-73.94628 45.52809, -73.94625 ...
# 2046  MULTIPOLYGON (((-73.84908 45.67620, -73.84797 ...
# 2047  MULTIPOLYGON (((-73.74770 45.66324, -73.74717 ...
# 2048  MULTIPOLYGON (((-73.74764 45.66324, -73.74751 ...
#
# [2049 rows x 334 columns]

# %%
all_opening_hours['opening_hours']
# Out:
# 0                               We-Su 10:00-17:00; Mo off
# 1                                       Mo-Su 11:00-23:00
# 2                                              6:00-22:00
# 3                                       Mo-Su 08:00-22:00
# 4                       Mo-Sa 06:00-15:00, Su 07:00-15:00
#                               ...
# 2044                 Mo-Fr 09:00-18:00; Sa-Su 09:00-17:00
# 2045                    Mo-Fr 08:30-18:00; Sa 08:00-13:00
# 2046    Apr-Nov: Th-Tu 08:00-17:00;Nov-Apr: Su 08:00-1...
# 2047                                           6:00-22:00
# 2048                                           6:00-22:00
# Name: opening_hours, Length: 2049, dtype: object

# %%
all_opening_hours['shop'].value_counts()
# Out:
# supermarket                  98
# convenience                  72
# clothes                      65
# hairdresser                  46
# bakery                       39
#                              ..
# cosmetics                     1
# bicycle,_scooter,_rentals     1
# photo                         1
# radiotechnics                 1
# tyres                         1
# Name: shop, Length: 107, dtype: int64

# %%
X_all = pd.read_csv('../../Data/model_inputs/gdf_2017_X.csv')
y_all = pd.read_csv('../../Data/model_inputs/gdf_2017_y.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-fef3a363a7db> in <module>
# ----> 1 X_all = pd.read_csv('../../Data/model_inputs/gdf_2017_X.csv')
#       2 y_all = pd.read_csv('../../Data/model_inputs/gdf_2017_y.csv')
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/anaconda3/envs/datasci/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../Data/model_inputs/gdf_2017_X.csv'

# %%
# COLUMNS_TO_USE = ['name','opening_hours','amenity','tourism', 'shop', 'healthcare', 'leisure', 'sport','craft', 'building','geometry']

# %%
# all_opening_hours[COLUMNS_TO_USE].to_csv('../Data/model_inputs/mtl_opening_hours_cleaned.csv',index=False, encoding='utf-8')
