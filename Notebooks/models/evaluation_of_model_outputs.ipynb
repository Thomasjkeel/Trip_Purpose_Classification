# %% [markdown]
# # Evaluation of models
# i.e. AUPRC and other evaluation metrics metrics
#
# confusion matrix
# spatial, temporal and spatial-temporal evaluation of the error terms

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
predictions_17 = pd.read_csv('../../Data/model_outputs/predictions_17.csv')

# %%
predictions_17.head()
# Out:
#    id_trip  mode  duration    distance_m  weekday        precip       temp  \
# 0   323826     2      1165  12233.968564        1  9.972328e-07  18.007062
# 1    14699     0      1668   1275.056162        1  2.742390e-05  25.618059
# 2   161711     3      1932   3306.383690        1  6.182843e-05  26.659408
# 3    74364     2       924   2635.616284        1  9.872605e-05  25.860051
# 4   260567     0      2021   4478.585678        1  9.872605e-05  25.860051
#
#    morning  midday  afternoon  evening  midnight        startx        starty  \
# 0    False    True      False    False     False  7.625699e+06  1.248427e+06
# 1    False   False       True    False     False  7.631673e+06  1.244415e+06
# 2    False   False      False     True     False  7.628139e+06  1.242935e+06
# 3    False   False      False     True     False  7.626550e+06  1.245312e+06
# 4    False   False      False     True     False  7.629452e+06  1.246949e+06
#
#            endx          endy  prediction  purpose
# 0  7.616671e+06  1.252917e+06           2        5
# 1  7.631896e+06  1.244344e+06           2        0
# 2  7.628353e+06  1.240487e+06           2        0
# 3  7.626002e+06  1.244753e+06           0        2
# 4  7.629776e+06  1.248377e+06           0        0
